# %% [markdown]
# # My First Notebook on IBM Watson Studio

# %% [markdown]
# **Maxwell Maciel**

# %% [markdown]
# I'm an electrical engineer and I'm studying to became a great Data Scientist.

# %% [markdown]
# *I am interested in data science because if you know how to use it you will always take the best decisions for the company and I love to be a part of that.*

# %% [markdown]
# ###    The following code is to show a litle operations the we learned until now.

# %%
a = 1
b = 2
c = 3

# %%
(a + b )*3
# Out:
# 9

# %%
c + a
# Out:
# 4

# %% [markdown]
# ---
#
#
# * Monday
# * Tuesday
# * Wednesday
#
#
# Markdown | Less | Pretty
# --- | --- | ---
# *Still* | `renders` | **nicely**
# 1 | 2 | 3
